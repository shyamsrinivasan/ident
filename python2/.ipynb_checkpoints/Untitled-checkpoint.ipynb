# %%
from sympy import *
from sympy.abc import x
expr=sin(x)/x
expr.evalf(subs={x:3.14})
# Out:
# 0.000507214304613640

# %%
from sympy import *
from sympy.abc import x
import numpy
expr=sin(x)/x
f=lambdify(x,expr)
data = numpy.linspace(1,10,100)
f(data)
# Out:
# array([ 0.84147098,  0.81312641,  0.78294368,  0.75106848,  0.71765394,
#         0.6828597 ,  0.64685106,  0.60979798,  0.57187409,  0.53325577,
#         0.49412106,  0.45464871,  0.41501716,  0.37540351,  0.3359826 ,
#         0.29692598,  0.25840103,  0.22057   ,  0.18358919,  0.14760808,
#         0.1127686 ,  0.07920436,  0.04704   ,  0.0163906 , -0.0126389 ,
#        -0.03995417, -0.06547189, -0.08912008, -0.11083839, -0.13057828,
#        -0.14830314, -0.16398831, -0.1776211 , -0.18920062, -0.19873766,
#        -0.20625439, -0.2117841 , -0.21537077, -0.21706864, -0.21694173,
#        -0.21506326, -0.21151503, -0.20638681, -0.19977558, -0.19178485,
#        -0.18252389, -0.1721069 , -0.16065222, -0.14828154, -0.13511901,
#        -0.1212904 , -0.10692233, -0.09214136, -0.0770732 , -0.06184195,
#        -0.04656925, -0.03137359, -0.01636956, -0.00166719,  0.01262868,
#         0.02641901,  0.03961113,  0.05211916,  0.06386451,  0.07477625,
# ...
